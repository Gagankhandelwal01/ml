# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import pickle

# %%
df = pd.read_csv("/content/placement.csv")
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['placement'].plot(kind='hist', bins=20, title='placement')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Unnamed: 0', y='cgpa', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='cgpa', y='iq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='iq', y='placement', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cgpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cgpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['iq']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('iq')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['placement']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('placement')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['cgpa'].plot(kind='line', figsize=(8, 4), title='cgpa')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['iq'].plot(kind='line', figsize=(8, 4), title='iq')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['placement'].plot(kind='line', figsize=(8, 4), title='placement')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
#STEPS

#0. PreProcess + EDA + Feature Selection.
#1. Extract input and output columns.
#2. Scale the Values.
#3. Train test split
#4. Train the model.
#5. Evaluate the model/ model selection.
#6. Deploy the Model.

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('CGPA vs IQ')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
X
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train
# Out:
#     Unnamed: 0  cgpa
# 77          77   7.3
# 60          60   6.9
# 31          31   3.9
# 97          97   6.7
# 84          84   5.7
# ..         ...   ...
# 34          34   4.8
# 51          51   4.8
# 17          17   3.3
# 74          74   6.7
# 19          19   5.2
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     Unnamed: 0  cgpa
# 82          82   6.5
# 92          92   5.2
# 91          91   7.5
# 1            1   5.9
# 9            9   5.1
# 76          76   4.9
# 66          66   6.9
# 3            3   7.4
# 57          57   6.5
# 24          24   4.7

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.98213194,  1.14224362],
#        [ 0.37646412,  0.7952329 ],
#        [-0.65673393, -1.8073475 ],
#        [ 1.69468232,  0.62172754],
#        [ 1.23152457, -0.24579926],
#        [ 0.48334667,  0.27471682],
#        [-0.44296882,  1.83626506],
#        [-0.5854789 ,  0.01445878],
#        [ 1.40966217, -0.9398207 ],
#        [-1.76118702,  0.70848022],
#        [-1.26240176,  0.10121146],
#        [-0.47859634, -0.24579926],
#        [-1.40491183,  0.01445878],
#        [-1.51179439, -0.85306802],
#        [ 0.66148427, -1.72059482],
#        [ 0.73273931,  0.27471682],
#        [ 1.33840713, -0.24579926],
#        [-0.69236145,  1.40250166],
#        [-0.72798897,  0.88198558],
#        [ 1.58779976, -1.11332606],
#        [-0.76361649, -0.67956266],
#        [ 1.44528969,  1.14224362],
#        [ 1.6590548 , -1.3735841 ],
#        [ 0.41209164,  1.14224362],
#        [ 1.01775946,  0.10121146],
#        [-0.87049905, -0.85306802],
#        [-0.33608626, -0.9398207 ],
#        [-1.58304943,  0.96873826],
#        [ 0.30520908,  1.74951238],
#        [ 0.3408366 , -1.02657338],
#        [-0.37171378, -1.20007874],
#        [-0.62110641,  0.88198558],
#        [ 1.73030984,  0.27471682],
#        [ 1.55217224,  0.70848022],
#        [ 0.12707148,  2.00977042],
#        [-1.04863664,  0.53497486],
#        [ 1.0890145 , -0.9398207 ],
#        [ 0.83962186, -0.9398207 ],
#        [ 0.80399435,  1.14224362],
#        [ 0.162699  ,  0.3614695 ],
#        [-1.11989168, -1.72059482],
#        [-0.19357619,  1.31574898],
#        [-1.54742191, -0.24579926],
#        [-0.83487153,  0.88198558],
#        [-1.47616687,  0.10121146],
#        [ 1.12464202, -0.5060573 ],
#        [ 0.23395404,  0.10121146],
#        [ 1.19589705,  1.31574898],
#        [-0.94175409, -1.11332606],
#        [-0.51422386,  0.70848022],
#        [-0.4073413 ,  0.44822218],
#        [-1.19114672, -0.67956266],
#        [ 1.26715209, -0.15904658],
#        [-0.79924401,  0.01445878],
#        [-0.15794867,  0.01445878],
#        [-0.9773816 , -0.9398207 ],
#        [-0.30045874, -0.5060573 ],
#        [-0.12232115, -0.59280998],
#        [-1.36928431,  0.7952329 ],
#        [-1.29802928,  0.3614695 ],
#        [ 1.30277961, -0.76631534],
#        [ 1.62342728, -1.46033678],
#        [ 0.76836683,  0.10121146],
#        [-1.68993198, -0.59280998],
#        [ 0.55460171,  1.83626506],
#        [-1.22677424, -0.76631534],
#        [-0.01543859, -0.5060573 ],
#        [-1.33365679, -0.5060573 ],
#        [-0.26483122,  1.40250166],
#        [ 0.9108769 , -1.02657338],
#        [ 0.19832652,  1.57600702],
#        [ 0.02018893, -2.15435822],
#        [ 1.76593736,  0.18796414],
#        [-1.01300912,  0.96873826],
#        [-0.05106611,  0.53497486],
#        [-0.08669363, -0.67956266],
#        [ 1.05338698,  0.44822218],
#        [-1.61867695, -0.15904658],
#        [ 0.69711179,  2.18327578],
#        [ 0.51897419,  0.88198558],
#        [ 0.09144397,  0.88198558],
#        [ 1.37403465, -1.3735841 ],
#        [-0.22920371,  0.70848022],
#        [ 0.44771916,  0.01445878],
#        [ 0.62585675, -0.85306802],
#        [-0.54985138, -1.02657338],
#        [ 0.05581645, -1.02657338],
#        [-1.1555192 , -2.32786358],
#        [ 0.87524938,  0.62172754],
#        [-1.08426416, -0.67956266]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.90528243,  0.44347268],
#        [ 1.18907002, -0.86678752],
#        [ 1.16069127,  1.45136515],
#        [-1.39339709, -0.16126279],
#        [-1.16636702, -0.96757676],
#        [ 0.73500987, -1.16915526],
#        [ 0.45122228,  0.84662967],
#        [-1.33663957,  1.3505759 ],
#        [ 0.19581344,  0.44347268],
#        [-0.74068562, -1.37073375]])

# %%
clf = LogisticRegression()

# %%
#MODEL TRAINING
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 82    1
# 92    0
# 91    1
# 1     0
# 9     0
# 76    0
# 66    1
# 3     1
# 57    1
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
pickle.dump(clf, open('model.pkl', 'wb'))
